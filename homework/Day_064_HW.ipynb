# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %%
import os
import numpy as np
import pandas as pd

# %%
data_path = 'data/'
df = pd.read_csv(data_path + 'day64_summary.csv')

# %%
df.head(11)
# Out:
#     Layer 1  Layer 2  Layer 3  Testing Loss  Training Loss
# 0         8        0        0         0.017          0.017
# 1         4        4        0         0.017          0.016
# 2         5        3        0         0.015          0.015
# 3         6        2        0         0.015          0.014
# 4         7        1        0         0.016          0.016
# 5         3        3        2         0.200          0.190
# 6         4        2        2         0.015          0.015
# 7         4        3        1         0.017          0.016
# 8         2        3        3         0.030          0.030
# 9         5        2        1         0.021          0.020
# 10        6        1        1         0.019          0.018

# %% [markdown]
# 在以上組合中，這個組合比較好，Layer1=6,Layer2=2, Testing Loss=0.015, Training Loss=0.014 ,

# %%
from IPython.display import Image
Image(filename='day64_1.png')
