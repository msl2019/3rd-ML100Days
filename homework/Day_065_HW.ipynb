# %% [markdown]
# # 作業
# * 選擇分類資料集(右下)-螺旋雙臂 - 交錯六群，限定特徵只能使用前兩個，隱藏層 2 層滿 (共 8 * 2 =16 個神經元)，
#   遞迴次數只允許跑到500次，但可以自由調整 批次大小、學習速率、啟動函數、正規化選項與參數
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的上述幾項參數與 Test Loss 數

# %%
import os
import numpy as np
import pandas as pd

# %%
data_path = 'data/'
df = pd.read_csv(data_path + 'day65_summary.csv')

# %%
df.head(25)
# Out:
#     Batch Size  Learning Rate Activation Regularization  Regularization rate  \
# 0           10           0.03       Tanh           None                0.000
# 1           10           0.03       Tanh             L1                0.030
# 2           10           0.03       Tanh             L2                0.030
# 3           10           1.00       Tanh           None                0.000
# 4           30           1.00       Tanh             L2                1.000
# 5           30           1.00    Sigmoid             L2                1.000
# 6           30           1.00       RELU             L2                1.000
# 7           30           1.00     Linear             L2                1.000
# 8           10           3.00       Tanh           None                0.000
# 9           30           3.00       Tanh           None                0.000
# 10          21           1.00       Tanh           None                0.000
# ...

# %% [markdown]
# 在以上組合中，第 18 這個組合比較好，,
#
# Batch Size=3, Learning Rate=0.03,Activation=RELU, Regularization=L1, Regularization rate=0
#
# Testing Loss=0.058, Training Loss=0.005

# %%
from IPython.display import Image
Image(filename='day65_1.png')
