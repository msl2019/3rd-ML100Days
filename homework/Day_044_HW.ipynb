# %% [markdown]
# ## [作業重點]
# 確保你了解隨機森林模型中每個超參數的意義，並觀察調整超參數對結果的影響

# %% [markdown]
# ## 作業
#
# 1. 試著調整 RandomForestClassifier(...) 中的參數，並觀察是否會改變結果？
# 2. 改用其他資料集 (boston, wine)，並與回歸模型與決策樹的結果進行比較

# %%
from sklearn import datasets, metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
# Wine
#嘗試使用不同的方法(gini,entropy)
#和 min_samples_split,min_samples_leaf,   
wine = datasets.load_wine()
x_train, x_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.25, random_state=4)
x_method = ['gini','entropy']
x_estimators =[10,20,30]
x_depth = [2,5,10]
x_split =[2,3,4]
x_leaf = [1,2,3]

# %%
for b_method in x_method:
    for b_estimators in x_estimators:
        for b_depth in x_depth:
            for b_split in x_split:
                for b_leaf in x_leaf:
                    clf = RandomForestClassifier(
                        n_estimators=b_estimators, 
                        criterion=b_method,
                        max_features="auto",
                        max_depth=b_depth,
                        min_samples_split=b_split,
                        min_samples_leaf=b_leaf
                    )

                    clf.fit(x_train, y_train)
                    y_pred = clf.predict(x_test)
                    acc = metrics.accuracy_score(y_test, y_pred)
                    print("Accuracy: ", acc)
                    print(wine.feature_names)
                    print("Feature importance: ", clf.feature_importances_)
                    print("Estimators:",b_estimators, ",Method:",b_method, ",max_depth:",b_depth, ",Min_sample_Split:",b_split,",min_samples_leaf:",b_leaf,"\n")
                    print("-----------------------------------------------------------")
# Out:
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [2.07456264e-01 0.00000000e+00 0.00000000e+00 1.93424309e-02
#  0.00000000e+00 2.94729819e-02 7.43502438e-02 1.97413435e-04
#  0.00000000e+00 2.49241574e-01 1.17816981e-01 2.16293582e-01
#  8.58285280e-02]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9555555555555556
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.12806105 0.03280067 0.         0.00461239 0.01213081 0.07982513
#  0.0170831  0.         0.06831041 0.04321164 0.15733358 0.17647602
#  0.28015521]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09220424 0.06030497 0.         0.01795279 0.07463629 0.10269735
#  0.25620604 0.         0.         0.19071602 0.0524052  0.02516523
#  0.12771187]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.31419552 0.02016027 0.         0.00897426 0.         0.07847308
#  0.12381884 0.         0.         0.12057876 0.14305607 0.15294365
#  0.03779955]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.06385972 0.         0.         0.01263851 0.01264963 0.09762013
#  0.09299433 0.03678718 0.         0.34249747 0.         0.13922274
#  0.2017303 ]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9555555555555556
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.02860357 0.         0.         0.         0.00077666 0.07264938
#  0.05893115 0.05287184 0.         0.12749322 0.0710165  0.2259809
#  0.36167679]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09988463 0.00335866 0.0091238  0.06084725 0.0342163  0.10381789
#  0.20322665 0.         0.01060528 0.12862242 0.04575309 0.18889885
#  0.11164518]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.17900693 0.02545217 0.         0.03268327 0.         0.
#  0.10900439 0.         0.00087128 0.07561706 0.08897607 0.15544238
#  0.33294646]
# Estimators: 10 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.
,Method: gini ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.22950067 0.04554244 0.00806692 0.02587163 0.01914013 0.09061899
#  0.10587817 0.01957623 0.03664431 0.15557101 0.07294778 0.08591737
#  0.10472433]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.07097306 0.00713552 0.00409546 0.0564763  0.00889055 0.0522473
#  0.27190864 0.         0.02203703 0.22140311 0.08629249 0.08709689
#  0.11144364]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.15681182 0.02012333 0.00088352 0.01339407 0.02490626 0.03717497
#  0.13372274 0.01897847 0.02673846 0.24379056 0.03653013 0.10174268
#  0.18520299]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.1008272  0.02274678 0.01782212 0.03956802 0.00341817 0.05918014
#  0.13747323 0.00315502 0.02811773 0.13114773 0.0652032  0.18661681
#  0.20472384]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09808554 0.02327518 0.01951967 0.01297803 0.04948382 0.0616689
#  0.22763899 0.00216246 0.0301444  0.10356201 0.07906087 0.13516006
#  0.15726006]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.12091292 0.         0.         0.00837735 0.04382501 0.01680506
#  0.14299888 0.00138094 0.02385285 0.23120172 0.08180952 0.14001865
#  0.18881711]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.11816344 0.01159729 0.0201472  0.01172079 0.03101203 0.08009141
#  0.18229864 0.         0.01696137 0.23557846 0.09461888 0.11896483
#  0.07884566]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14830698 0.00371353 0.02694748 0.03749468 0.02811955 0.05617121
#  0.17862328 0.         0.04430392 0.17405336 0.07612899 0.08406799
#  0.14206903]
# Estimators: 30 ,Method: gini ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.12935788 0.02596167 0.00588357 0.03811006 0.0454109  0.04324127
#  0.13600186 0.00313858 0.05140788 0.17419115 0.06512592 0.12106425
#  0.16110501]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.05621491 0.05383759 0.00272358 0.03818484 0.01856343 0.04347273
#  0.15664097 0.00802532 0.01885852 0.24145768 0.04377304 0.11211978
#  0.20612761]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.16788459 0.03113588 0.01230475 0.02384392 0.05567226 0.05648708
#  0.10230839 0.00593892 0.02261023 0.19169492 0.10270727 0.10320544
#  0.12420634]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.17938034 0.02085224 0.01382354 0.0439543  0.02277069 0.05911025
#  0.15955582 0.006563   0.01318312 0.12425324 0.06902107 0.10211789
#  0.18541449]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.22616666 0.01474604 0.01025739 0.03512393 0.03553531 0.07150474
#  0.10602813 0.01894012 0.03170214 0.11466331 0.06610546 0.13843729
#  0.13078948]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.15636807 0.04417597 0.00146253 0.03442236 0.03903352 0.04855358
#  0.15459456 0.01415661 0.01102244 0.17550175 0.05015747 0.10461256
#  0.16593858]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.15218555 0.02000696 0.0118539  0.03466028 0.025759   0.07741434
#  0.12878718 0.00781263 0.01620042 0.15566907 0.10003531 0.08703786
#  0.18257749]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10726244 0.02096223 0.01065843 0.01672442 0.02214583 0.05093849
#  0.14103373 0.00745244 0.00540242 0.17006709 0.09946083 0.1032869
#  0.24460475]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10733082 0.02150215 0.00498061 0.01821033 0.04780221 0.06395134
#  0.07070489 0.01423175 0.02314005 0.1729585  0.09117603 0.16943862
#  0.19457271]
# Estimators: 30 ,Method: gini ,max_depth: 5 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10853773 0.02008411 0.00902683 0.04281768 0.03759813 0.04771158
#  0.13603566 0.00361536 0.01742596 0.17314078 0.02653783 0.12247242
#  0.25499594]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.15038559 0.02513356 0.01794533 0.04329684 0.05758578 0.0855667
#  0.14177158 0.01108924 0.01983242 0.18275176 0.04849412 0.07941945
#  0.13672764]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.13840117 0.04447568 0.00608925 0.0458441  0.03137937 0.0286621
#  0.20406137 0.00876205 0.02418222 0.16395526 0.05879286 0.08727815
#  0.15811643]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14305491 0.02743696 0.00964314 0.0252847  0.03596542 0.03758469
#  0.12561934 0.01012766 0.04603269 0.12664065 0.10274294 0.11061529
#  0.19925159]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.17554203 0.00922956 0.01399789 0.03667152 0.04222053 0.06049681
#  0.10701708 0.00696765 0.0201804  0.11351671 0.05367429 0.16161027
#  0.19887526]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.12622402 0.0131275  0.01096339 0.02549599 0.02737266 0.02504995
#  0.17046118 0.01003567 0.02408946 0.1187918  0.07796111 0.15700567
#  0.21342158]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.18083569 0.02599578 0.01293209 0.02905284 0.03555735 0.04451514
#  0.18540576 0.01181812 0.02464251 0.16250477 0.0569054  0.07862966
#  0.15120489]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.13424701 0.01857048 0.01359416 0.03121289 0.02575065 0.06504966
#  0.0785772  0.00333787 0.02757526 0.19085616 0.07427435 0.14038804
#  0.19656627]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.05957123 0.03081283 0.0128287  0.01928892 0.0410873  0.04943539
#  0.11388875 0.00913163 0.01138637 0.21154134 0.06062205 0.13338205
#  0.24702345]
# Estimators: 30 ,Method: gini ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14696218 0.03474415 0.         0.         0.02217297 0.04017287
#  0.05987643 0.         0.09035294 0.17924225 0.0873231  0.17916364
#  0.15998946]
# Estimators: 10 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.07677763 0.00877606 0.         0.0048476  0.00969659 0.02438309
#  0.10746071 0.         0.00364914 0.15078301 0.0552371  0.24221317
#  0.3161759 ]
# Estimators: 10 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9555555555555556
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.11692364 0.01688645 0.         0.08413568 0.01992852 0.1513075
#  0.18370006 0.01446187 0.05282768 0.0347936  0.03942605 0.19927666
#  0.0863323 ]
# Estimators: 10 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.23915087 0.00634505 0.03756769 0.06119652 0.         0.09188778
#  0.19855646 0.         0.         0.08365116 0.1339534  0.07992747
#  0.06776359]
# Estimators: 10 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9333333333333333
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10935478 0.02574186 0.         0.04372244 0.         0.
#  0.2037148  0.01317908 0.02979746 0.28289158 0.02617635 0.1633463
#  0.10207536]
# Estimators: 10 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.19433288 0.         0.00936174 0.         0.         0.04238793
#  0.10989296 0.01018539 0.02076823 0.15092667 0.10482406 0.1372473
#  0.22007284]
# Estimators: 10 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# ...
# Feature importance:  [0.09252342 0.02778974 0.00420238 0.03553752 0.05794126 0.0737721
#  0.18257641 0.00585352 0.01635004 0.15722089 0.06766621 0.09582355
#  0.18274295]
# Estimators: 20 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.04859738 0.0258234  0.02412843 0.01658196 0.01838292 0.05960864
#  0.17421526 0.00990174 0.0041358  0.21517826 0.12163718 0.10451156
#  0.17729748]
# Estimators: 20 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09154436 0.01833411 0.         0.04167722 0.03233904 0.05575779
#  0.18166644 0.00420843 0.00621016 0.14653023 0.09148196 0.12653786
#  0.20371241]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09877649 0.03704892 0.00631102 0.03203823 0.00322524 0.10589899
#  0.1144673  0.03517981 0.00702243 0.16663399 0.03960173 0.18175944
#  0.17203641]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14401691 0.01009624 0.00148113 0.02434737 0.00513414 0.06233123
#  0.15597807 0.         0.02396247 0.10473359 0.08986317 0.22148566
#  0.15657002]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10053499 0.00380492 0.00430502 0.02239345 0.01967643 0.06207361
#  0.15887684 0.00612573 0.01433035 0.164256   0.05894794 0.17175424
#  0.21292047]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14254077 0.01693    0.01151928 0.03672692 0.01312262 0.06237881
#  0.17614244 0.         0.01268796 0.15391517 0.07992194 0.12588187
#  0.16823223]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9555555555555556
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.18502546 0.04516923 0.00388881 0.00674522 0.00996689 0.04947365
#  0.15407418 0.00817425 0.00882403 0.19187583 0.09934422 0.09063415
#  0.14680408]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.18938032 0.02686313 0.01680146 0.02737347 0.00925905 0.00908213
#  0.15832682 0.00169232 0.03049989 0.17353772 0.03512904 0.17438606
#  0.14766858]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9555555555555556
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14624517 0.04331013 0.0017733  0.06839745 0.         0.05862107
#  0.13312814 0.01715952 0.01407907 0.17160275 0.09300689 0.14158798
#  0.11108852]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.11193597 0.04876103 0.00701508 0.01274995 0.04826955 0.08574773
#  0.19633202 0.00596707 0.00355    0.16019449 0.08426949 0.09191926
#  0.14328837]
# Estimators: 30 ,Method: entropy ,max_depth: 2 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.13893593 0.01510933 0.0178028  0.0450231  0.03097341 0.03913358
#  0.17008301 0.01212736 0.0348454  0.16840841 0.05614645 0.15407266
#  0.11733855]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.08697966 0.01420641 0.00659336 0.02884175 0.02165616 0.05498095
#  0.15066669 0.00745232 0.02198347 0.20392569 0.08526443 0.12856341
#  0.18888568]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.1252707  0.01497691 0.00825708 0.03805074 0.0360895  0.05323469
#  0.23088852 0.0142225  0.02318536 0.14795822 0.04417103 0.10411107
#  0.15958369]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.11605802 0.01804345 0.01746081 0.03236403 0.04676425 0.03541048
#  0.16215164 0.00631114 0.03008381 0.15840074 0.08425217 0.12134024
#  0.17135922]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.13460042 0.02699593 0.00970772 0.03787329 0.05735467 0.08086326
#  0.16855791 0.01001396 0.00740036 0.12382001 0.08918422 0.14237843
#  0.11124984]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.0961722  0.03133443 0.01110874 0.01921097 0.03787785 0.04058645
#  0.19704463 0.00538444 0.0285864  0.18350619 0.03574949 0.12880126
#  0.18463697]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10919427 0.03516509 0.01434202 0.03346455 0.02887704 0.07427775
#  0.09943963 0.00620829 0.02014042 0.18521767 0.11404658 0.12227527
#  0.15735143]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.06309243 0.01981657 0.00608952 0.03432776 0.03376786 0.0738276
#  0.16890752 0.00612522 0.02152776 0.20233435 0.08836408 0.12562189
#  0.15619742]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.14052663 0.03259863 0.01157059 0.00903173 0.03205006 0.08825726
#  0.1373881  0.00745921 0.01204111 0.20530653 0.08054822 0.1161639
#  0.12705802]
# Estimators: 30 ,Method: entropy ,max_depth: 5 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.11403571 0.03471178 0.00999876 0.01626094 0.03445601 0.06074946
#  0.14562458 0.00655612 0.01362026 0.12788187 0.06376423 0.16800787
#  0.20433242]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 2 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.08613906 0.01673275 0.01320573 0.02907409 0.02041703 0.0665549
#  0.13222147 0.00858455 0.036959   0.21658303 0.08456356 0.12550795
#  0.16345687]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 2 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09412774 0.03536255 0.01266034 0.02845149 0.02220276 0.07060114
#  0.13571938 0.00683652 0.02383047 0.20712812 0.06852787 0.13340982
#  0.1611418 ]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 2 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.10825926 0.04300723 0.01451993 0.04129855 0.02581203 0.0601614
#  0.10760027 0.01007087 0.0275589  0.16542874 0.06592177 0.15407749
#  0.17628356]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 3 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.151282   0.02694908 0.01035335 0.03023214 0.02674551 0.09425256
#  0.17329007 0.00948305 0.0220234  0.13260935 0.10374915 0.06335449
#  0.15567583]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 3 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09871528 0.02482226 0.01467695 0.02836168 0.0247593  0.04085109
#  0.11066754 0.0067777  0.0290177  0.2101074  0.08577549 0.15488298
#  0.17058462]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 3 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
# Accuracy:  1.0
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.15735009 0.02675531 0.0101908  0.05473458 0.02425987 0.07944045
#  0.1409022  0.00451236 0.03893884 0.13971102 0.08914575 0.11777528
#  0.11628345]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 1
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.09610148 0.03741323 0.01176062 0.05087254 0.03232025 0.04680005
#  0.14487309 0.0080403  0.03104703 0.14222425 0.05689071 0.19540214
#  0.14625431]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 2
#
# -----------------------------------------------------------
# Accuracy:  0.9777777777777777
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Feature importance:  [0.07370482 0.01662647 0.01355978 0.02029803 0.02560601 0.10338182
#  0.11319569 0.01021767 0.01911188 0.20809364 0.07260375 0.07828109
#  0.24531936]
# Estimators: 30 ,Method: entropy ,max_depth: 10 ,Min_sample_Split: 4 ,min_samples_leaf: 3
#
# -----------------------------------------------------------
